# %%
import glob
import os
from PIL import Image
import nibabel 
import time
import sys
import shutil
from files2txt2files import read_list_from_file, save_list_to_file
import json
import numpy as np
import matplotlib.pyplot as plt


np_mr_arr = np.zeros((3001, 1))

np_ct_arr = np.zeros((4001, 1))

def nii_to_matrix_dict(folder, bad_data_file):

    bad_data = read_list_from_file(bad_data_file)

    partitions = [os.path.join(folder,dir) for dir in os.listdir(folder) if os.path.isdir(os.path.join(folder, dir))]
    for i, partition in enumerate(partitions):

        print(f"Starting work on partition \"{partition}\" ({i+1}/{len(partitions)})")

        #patient folders (some might not be..)
        patients = [os.path.join(partition,dir) for dir in os.listdir(partition) if (os.path.isdir(os.path.join(partition, dir)))]

        #enter each patient folder
        for patient in patients:

            patient_id = patient.split("/")[-1]
            print(f" Starting work on patient \"{patient_id}\"")
            os.chdir(patient) # I believe this is not needed

            #converts each scan of the patient individually
            for scan in glob.glob('*.nii.gz'):

                #we do not use the mask files so we delete then
                if scan == 'mask.nii.gz':
                    os.remove(scan)
                    continue

                #load the .nii.gz file
                nii = nibabel.load(scan)
                np_arr = np.asarray(nii.dataobj)

                for slice in range(np_arr.shape[2]):

                    # if (f"{patient_id}-{slice:03}" in bad_data):
                    #     continue                    

                    # clean_arr.append(np_arr[:, :, slice])

                    #Minmaxnorm + scale as image
                    if (scan.split(".")[0] == "ct"):
                        for elm in np_arr[:, :, slice].flatten():
                            np_ct_arr[int(elm + 1000)] += 1
                        

                    if (scan.split(".")[0] == "mr"):    
                        for elm in np_arr[:, :, slice].flatten():
                            np_mr_arr[int(elm)] += 1

                del np_arr 
                del nii

# %%
def clean_folder(folder):
    print("Cleaning")
    dirs = [os.path.join(folder,dir) for dir in os.listdir(folder) if os.path.isdir(os.path.join(folder, dir))]

    for dir in dirs:
        shutil.rmtree(dir)

    zips = [os.path.join(folder,elm) for elm in os.listdir(folder) if elm.split(".")[-1] == "zip"]

    for z in zips:
        shutil.unpack_archive(z,folder)
    print("Done cleaning")

# %%
# clean_folder("/Users/andershelbo/Desktop/MAKEDATA/Input_data")

start = time.time()
nii_to_matrix_dict("/Users/andershelbo/Desktop/MAKEDATA/Input_data", "/Users/andershelbo/Desktop/MAKEDATA/test_data.txt")
end = time.time()
# Out:
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/pelvis1" (1/17)
#  Starting work on patient "1PA041"
#  Starting work on patient "1PA070"
#  Starting work on patient "1PA048"
#  Starting work on patient "1PA049"
#  Starting work on patient "1PA047"
#  Starting work on patient "1PA040"
#  Starting work on patient "1PA038"
#  Starting work on patient "1PA031"
#  Starting work on patient "1PA062"
#  Starting work on patient "1PA065"
#  Starting work on patient "1PA053"
#  Starting work on patient "1PA054"
#  Starting work on patient "1PA030"
#  Starting work on patient "1PA052"
#  Starting work on patient "1PA064"
#  Starting work on patient "1PA063"
#  Starting work on patient "1PA029"
#  Starting work on patient "1PA045"
#  Starting work on patient "1PA028"
#  Starting work on patient "1PA026"
#  Starting work on patient "1PA044"
#  Starting work on patient "1PA059"
#  Starting work on patient "1PA035"
#  Starting work on patient "1PA056"
#  Starting work on patient "1PA060"
#  Starting work on patient "1PA058"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/brain0" (2/17)
#  Starting work on patient "1BA082"
#  Starting work on patient "1BA076"
#  Starting work on patient "1BA085"
#  Starting work on patient "1BA040"
#  Starting work on patient "1BA014"
#  Starting work on patient "1BA022"
#  Starting work on patient "1BA012"
#  Starting work on patient "1BA105"
#  Starting work on patient "1BA103"
#  Starting work on patient "1BA111"
#  Starting work on patient "1BA116"
#  Starting work on patient "1BA001"
#  Starting work on patient "1BA097"
#  Starting work on patient "1BA091"
#  Starting work on patient "1BA054"
#  Starting work on patient "1BA075"
#  Starting work on patient "1BA100"
#  Starting work on patient "1BA058"
#  Starting work on patient "1BA005"
#  Starting work on patient "1BA032"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/brain7" (3/17)
#  Starting work on patient "1BC050"
#  Starting work on patient "1BC051"
#  Starting work on patient "1BC056"
#  Starting work on patient "1BC058"
#  Starting work on patient "1BC038"
#  Starting work on patient "1BC036"
#  Starting work on patient "1BC062"
#  Starting work on patient "1BC065"
#  Starting work on patient "1BC053"
#  Starting work on patient "1BC054"
#  Starting work on patient "1BC037"
#  Starting work on patient "1BC039"
#  Starting work on patient "1BC052"
#  Starting work on patient "1BC064"
#  Starting work on patient "1BC063"
#  Starting work on patient "1BC041"
#  Starting work on patient "1BC046"
#  Starting work on patient "1BC048"
#  Starting work on patient "1BC049"
#  Starting work on patient "1BC047"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/brain6" (4/17)
#  Starting work on patient "1BC004"
#  Starting work on patient "1BC035"
#  Starting work on patient "1BC034"
#  Starting work on patient "1BC027"
#  Starting work on patient "1BC020"
#  Starting work on patient "1BC010"
#  Starting work on patient "1BC017"
#  Starting work on patient "1BC028"
#  Starting work on patient "1BC021"
#  Starting work on patient "1BC019"
#  Starting work on patient "1BC007"
#  Starting work on patient "1BC031"
#  Starting work on patient "1BC009"
#  Starting work on patient "1BC008"
#  Starting work on patient "1BC006"
#  Starting work on patient "1BC001"
#  Starting work on patient "1BC023"
#  Starting work on patient "1BC014"
#  Starting work on patient "1BC025"
#  Starting work on patient "1BC022"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/brain1" (5/17)
#  Starting work on patient "1BA220"
#  Starting work on patient "1BA227"
#  Starting work on patient "1BA158"
#  Starting work on patient "1BA151"
#  Starting work on patient "1BA159"
#  Starting work on patient "1BA143"
#  Starting work on patient "1BA175"
#  Starting work on patient "1BA172"
#  Starting work on patient "1BA189"
#  Starting work on patient "1BA234"
#  Starting work on patient "1BA222"
#  Starting work on patient "1BA164"
#  Starting work on patient "1BA131"
#  Starting work on patient "1BA185"
#  Starting work on patient "1BA125"
#  Starting work on patient "1BA184"
#  Starting work on patient "1BA141"
#  Starting work on patient "1BA201"
#  Starting work on patient "1BA206"
#  Starting work on patient "1BA239"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/brain8" (6/17)
#  Starting work on patient "1BC066"
#  Starting work on patient "1BC068"
#  Starting work on patient "1BC094"
#  Starting work on patient "1BC067"
#  Starting work on patient "1BC080"
#  Starting work on patient "1BC074"
#  Starting work on patient "1BC073"
#  Starting work on patient "1BC087"
#  Starting work on patient "1BC086"
#  Starting work on patient "1BC075"
#  Starting work on patient "1BC081"
#  Starting work on patient "1BC088"
#  Starting work on patient "1BC090"
#  Starting work on patient "1BC070"
#  Starting work on patient "1BC084"
#  Starting work on patient "1BC083"
#  Starting work on patient "1BC077"
#  Starting work on patient "1BC076"
#  Starting work on patient "1BC082"
#  Starting work on patient "1BC085"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/pelvis0" (7/17)
#  Starting work on patient "1PA024"
#  Starting work on patient "1PA012"
#  Starting work on patient "1PA014"
#  Starting work on patient "1PA025"
#  Starting work on patient "1PA022"
#  Starting work on patient "1PA009"
#  Starting work on patient "1PA001"
#  Starting work on patient "1PA018"
#  Starting work on patient "1PA020"
#  Starting work on patient "1PA011"
#  Starting work on patient "1PA010"
#  Starting work on patient "1PA021"
#  Starting work on patient "1PA019"
#  Starting work on patient "1PA004"
#  Starting work on patient "1PA005"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/pelvic25" (8/17)
#  Starting work on patient "1PA079"
#  Starting work on patient "1PA084"
#  Starting work on patient "1PA083"
#  Starting work on patient "1PA076"
#  Starting work on patient "1PA091"
#  Starting work on patient "1PA098"
#  Starting work on patient "1PA090"
#  Starting work on patient "1PA097"
#  Starting work on patient "1PA100"
#  Starting work on patient "1PA101"
#  Starting work on patient "1PA074"
#  Starting work on patient "1PA080"
#  Starting work on patient "1PA086"
#  Starting work on patient "1PA081"
#  Starting work on patient "1PA088"
#  Starting work on patient "1PA095"
#  Starting work on patient "1PA094"
#  Starting work on patient "1PA093"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/pelvis35" (9/17)
#  Starting work on patient "1PA134"
#  Starting work on patient "1PA133"
#  Starting work on patient "1PA127"
#  Starting work on patient "1PA118"
#  Starting work on patient "1PA126"
#  Starting work on patient "1PA119"
#  Starting work on patient "1PA121"
#  Starting work on patient "1PA117"
#  Starting work on patient "1PA136"
#  Starting work on patient "1PA138"
#  Starting work on patient "1PA137"
#  Starting work on patient "1PA073"
#  Starting work on patient "1PA141"
#  Starting work on patient "1PA140"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/pelvis2" (10/17)
#  Starting work on patient "1PA105"
#  Starting work on patient "1PA111"
#  Starting work on patient "1PA116"
#  Starting work on patient "1PA110"
#  Starting work on patient "1PA109"
#  Starting work on patient "1PA107"
#  Starting work on patient "1PA106"
#  Starting work on patient "1PA108"
#  Starting work on patient "1PA115"
#  Starting work on patient "1PA112"
#  Starting work on patient "1PA113"
#  Starting work on patient "1PA114"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/pelvis5" (11/17)
#  Starting work on patient "1PC069"
#  Starting work on patient "1PC093"
#  Starting work on patient "1PC058"
#  Starting work on patient "1PC033"
#  Starting work on patient "1PC092"
#  Starting work on patient "1PC066"
#  Starting work on patient "1PC059"
#  Starting work on patient "1PC061"
#  Starting work on patient "1PC095"
#  Starting work on patient "1PC057"
#  Starting work on patient "1PC035"
#  Starting work on patient "1PC032"
#  Starting work on patient "1PC019"
#  Starting work on patient "1PC088"
#  Starting work on patient "1PC044"
#  Starting work on patient "1PC027"
#  Starting work on patient "1PC029"
#  Starting work on patient "1PC045"
#  Starting work on patient "1PC042"
#  Starting work on patient "1PC080"
#  Starting work on patient "1PC073"
#  Starting work on patient "1PC037"
#  Starting work on patient "1PC039"
#  Starting work on patient "1PC055"
#  Starting work on patient "1PC052"
#  Starting work on patient "1PC097"
#  Starting work on patient "1PC063"
#  Starting work on patient "1PC038"
#  Starting work on patient "1PC036"
#  Starting work on patient "1PC096"
#  Starting work on patient "1PC065"
#  Starting work on patient "1PC098"
#  Starting work on patient "1PC054"
#  Starting work on patient "1PC049"
#  Starting work on patient "1PC082"
#  Starting work on patient "1PC085"
#  Starting work on patient "1PC071"
#  Starting work on patient "1PC078"
#  Starting work on patient "1PC040"
#  Starting work on patient "1PC022"
#  Starting work on patient "1PC041"
#  Starting work on patient "1PC079"
#  Starting work on patient "1PC046"
#  Starting work on patient "1PC070"
#  Starting work on patient "1PC084"
#  Starting work on patient "1PC048"
#  Starting work on patient "1PC077"
#  Starting work on patient "1PC023"
#  Starting work on patient "1PC024"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/brain4" (12/17)
#  Starting work on patient "1BB051"
#  Starting work on patient "1BB066"
#  Starting work on patient "1BB059"
#  Starting work on patient "1BB095"
#  Starting work on patient "1BB050"
#  Starting work on patient "1BB072"
#  Starting work on patient "1BB075"
#  Starting work on patient "1BB073"
#  Starting work on patient "1BB052"
#  Starting work on patient "1BB090"
#  Starting work on patient "1BB062"
#  Starting work on patient "1BB096"
#  Starting work on patient "1BB091"
#  Starting work on patient "1BB049"
#  Starting work on patient "1BB076"
#  Starting work on patient "1BB082"
#  Starting work on patient "1BB085"
#  Starting work on patient "1BB071"
#  Starting work on patient "1BB079"
#  Starting work on patient "1BB083"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/brain3" (13/17)
#  Starting work on patient "1BB033"
#  Starting work on patient "1BB034"
#  Starting work on patient "1BB002"
#  Starting work on patient "1BB005"
#  Starting work on patient "1BB003"
#  Starting work on patient "1BB017"
#  Starting work on patient "1BB028"
#  Starting work on patient "1BB026"
#  Starting work on patient "1BB043"
#  Starting work on patient "1BB044"
#  Starting work on patient "1BB016"
#  Starting work on patient "1BB011"
#  Starting work on patient "1BB008"
#  Starting work on patient "1BB030"
#  Starting work on patient "1BB039"
#  Starting work on patient "1BB006"
#  Starting work on patient "1BB007"
#  Starting work on patient "1BB031"
#  Starting work on patient "1BB041"
#  Starting work on patient "1BB048"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/brain2" (14/17)
#  Starting work on patient "1BA288"
#  Starting work on patient "1BA300"
#  Starting work on patient "1BA307"
#  Starting work on patient "1BA336"
#  Starting work on patient "1BA325"
#  Starting work on patient "1BA379"
#  Starting work on patient "1BA294"
#  Starting work on patient "1BA260"
#  Starting work on patient "1BA256"
#  Starting work on patient "1BA292"
#  Starting work on patient "1BA266"
#  Starting work on patient "1BA247"
#  Starting work on patient "1BA278"
#  Starting work on patient "1BA305"
#  Starting work on patient "1BA358"
#  Starting work on patient "1BA359"
#  Starting work on patient "1BA368"
#  Starting work on patient "1BA328"
#  Starting work on patient "1BA345"
#  Starting work on patient "1BA253"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/brain5" (15/17)
#  Starting work on patient "1BB200"
#  Starting work on patient "1BB171"
#  Starting work on patient "1BB182"
#  Starting work on patient "1BB177"
#  Starting work on patient "1BB184"
#  Starting work on patient "1BB179"
#  Starting work on patient "1BB152"
#  Starting work on patient "1BB109"
#  Starting work on patient "1BB100"
#  Starting work on patient "1BB198"
#  Starting work on patient "1BB205"
#  Starting work on patient "1BB099"
#  Starting work on patient "1BB098"
#  Starting work on patient "1BB175"
#  Starting work on patient "1BB111"
#  Starting work on patient "1BB173"
#  Starting work on patient "1BB189"
#  Starting work on patient "1BB145"
#  Starting work on patient "1BB151"
#  Starting work on patient "1BB102"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/pelvis4" (16/17)
#  Starting work on patient "1PA168"
#  Starting work on patient "1PA167"
#  Starting work on patient "1PA169"
#  Starting work on patient "1PC004"
#  Starting work on patient "1PC010"
#  Starting work on patient "1PC017"
#  Starting work on patient "1PA187"
#  Starting work on patient "1PA173"
#  Starting work on patient "1PA174"
#  Starting work on patient "1PA180"
#  Starting work on patient "1PC018"
#  Starting work on patient "1PC011"
#  Starting work on patient "1PA188"
#  Starting work on patient "1PA181"
#  Starting work on patient "1PC006"
#  Starting work on patient "1PC001"
#  Starting work on patient "1PA165"
#  Starting work on patient "1PC000"
#  Starting work on patient "1PC007"
#  Starting work on patient "1PA164"
#  Starting work on patient "1PA177"
#  Starting work on patient "1PA183"
#  Starting work on patient "1PA170"
#  Starting work on patient "1PC013"
#  Starting work on patient "1PA178"
#  Starting work on patient "1PA171"
#  Starting work on patient "1PA185"
#  Starting work on patient "1PA182"
#  Starting work on patient "1PA176"
#  Starting work on patient "1PC015"
# Starting work on partition "/Users/andershelbo/Desktop/MAKEDATA/Input_data/pelvis3" (17/17)
#  Starting work on patient "1PA150"
#  Starting work on patient "1PA157"
#  Starting work on patient "1PA161"
#  Starting work on patient "1PA159"
#  Starting work on patient "1PA156"
#  Starting work on patient "1PA151"
#  Starting work on patient "1PA142"
#  Starting work on patient "1PA145"
#  Starting work on patient "1PA144"
#  Starting work on patient "1PA154"
#  Starting work on patient "1PA163"
#  Starting work on patient "1PA152"
#  Starting work on patient "1PA155"
#  Starting work on patient "1PA148"
#  Starting work on patient "1PA146"
#  Starting work on patient "1PA147"

# %%
def histogram_ct():
    global np_ct_arr
    plt.hist(np_ct_arr, bins=4001, range=(0, 4000))
    plt. title( 'Histogram - CT' )
    plt.xlabel ( 'Value')
    plt.ylabel('Frequency')
    plt.grid (True)
    #plt.ylim([0, 20])
    plt.yscale('log') 
    
    plt.show()

histogram_ct()

# %%
def histogram_mr():
    global np_mr_arr
    plt.hist(np_mr_arr, bins=4001, range=(0, 4000))
    plt. title( 'Histogram - CT' )
    plt.xlabel ( 'Value')
    plt.ylabel('Frequency')
    plt.grid (True)
    #plt.ylim([0, 20])
    plt.yscale('log') 
    
    plt.show()

histogram_mr()

# %%
def plot_mr():
    global np_mr_arr

    # Compute mean and standard deviation
    mean = np.mean(np_mr_arr)
    std_dev = np.std(np_mr_arr)
    
    # Plot mean
    # plt.axvline(mean, color='r', linestyle='dashed', linewidth=1, label='Mean')
    
    # Plot one standard deviation above and below the mean
    # plt.axvline(mean + std_dev, color='g', linestyle='dashed', linewidth=1, label='Mean ± 1 Std Dev')
    # plt.axvline(mean - std_dev, color='g', linestyle='dashed', linewidth=1)
    
    # Plot two standard deviations above and below the mean
    # plt.axvline(mean + 2*std_dev, color='b', linestyle='dashed', linewidth=1, label='Mean ± 2 Std Dev')
    # plt.axvline(mean - 2*std_dev, color='b', linestyle='dashed', linewidth=1)

    y_values = np.array(np_mr_arr)
    x_values = np.arange(len(y_values))
    plt.scatter(x_values, y_values)
    plt.xlabel('Intensity')
    plt.ylabel('Frequency)')
    plt.title('MR plot')
    plt.yscale('log')  # Set y-axis scale to logarithmic
    plt.grid(True)
    plt.show()

def plot_ct():
    global np_ct_arr

    # Compute mean and standard deviation
    mean = np.mean(np_ct_arr)
    std_dev = np.std(np_ct_arr)
    
    # Plot mean
    # plt.axvline(mean, color='r', linestyle='dashed', linewidth=1, label='Mean')
    
    # Plot one standard deviation above and below the mean
    # plt.axvline(mean + std_dev, color='g', linestyle='dashed', linewidth=1, label='Mean ± 1 Std Dev')
    # plt.axvline(mean - std_dev, color='g', linestyle='dashed', linewidth=1)
    
    # Plot two standard deviations above and below the mean
    # plt.axvline(mean + 2*std_dev, color='b', linestyle='dashed', linewidth=1, label='Mean ± 2 Std Dev')
    # plt.axvline(mean - 2*std_dev, color='b', linestyle='dashed', linewidth=1)

    y_values = np.array(np_ct_arr)
    # y_values = np.log(y_values)    
    x_values = np.arange(-1000, len(y_values) - 1000)
    plt.scatter(x_values, y_values, s=1)
    plt.xlabel('Intensity')
    plt.ylabel('Frequency')
    plt.title('CT plot')
    plt.yscale('log')  # Set y-axis scale to logarithmic
    plt.grid(True)
    plt.show()  

plot_ct()
plot_mr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 58
#      55     plt.grid(True)
#      56     plt.show()
# ---> 58 plot_ct()
#      59 plot_mr()
#
# Cell In[1], line 33, in plot_ct()
#      30 global np_ct_arr
#      32 # Compute mean and standard deviation
# ---> 33 mean = np.mean(np_ct_arr)
#      34 std_dev = np.std(np_ct_arr)
#      36 # Plot mean
#      37 # plt.axvline(mean, color='r', linestyle='dashed', linewidth=1, label='Mean')
#      38
#    (...)
#      44 # plt.axvline(mean + 2*std_dev, color='b', linestyle='dashed', linewidth=1, label='Mean ± 2 Std Dev')
#      45 # plt.axvline(mean - 2*std_dev, color='b', linestyle='dashed', linewidth=1)
#
# NameError: name 'np' is not defined
